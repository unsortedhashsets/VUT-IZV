# %% [markdown]
# # Test prerekvizitních znalostí Pythonu
# Na tomto testu byste si měli ověřit, zda chápete základní struktury a konstrukce v jazyku Python.
#
# _Odhadovaná doba řešení:_ 10 minut
#
# _Odevzdávání:_ tento soubor `test.ipynb` odevzdejte do WISu do čtvrtka 24. září 2020
#
# _Dotazy:_ fórum ve WISu, hodnotit bude V. Mrázek

# %%
# test verze jazyka Python
import sys
print(sys.version)
# mela by byt Python 3.8
# Out:
# 3.8.5 (default, Sep 22 2020, 13:05:10)
# [GCC 8.3.1 20191121 (Red Hat 8.3.1-5)]

# %%
# TODO: vypište váš login
print("xabram00")
# Out:
# xabram00

# %% [markdown]
# ## Část 1: funkce
#
# - Napište funci `f1` s proměnným počtem __pozičně nezávislých__ argumentů, která vypíše všechny argumenty ve formátu
# ```
# param1=hodnota1
# param2=hodnota2
# param3=hodnota3
# param4=hodnota4
# ```

# %%
# Funkce s proměnným počtem argumentů
# TODO: napiste funkci f1
def f1(**kwargs):
    for k, v in kwargs.items():
        print(f'{k}={v}')

f1(param1="hodnota1", param2="hodnota2", param3="hodnota3", param4="hodnota4")
# Out:
# param1=hodnota1
# param2=hodnota2
# param3=hodnota3
# param4=hodnota4

# %% [markdown]
# Zavolejte tuto funkci s parametry param1=hodnota1, param2=hodnota2, ... param100=hodnota100. Abyste nemuseli psát 100 různých výsledků, předejte je přes objekt typu `dictionary`. Zřejmě k tomu využijete výčet `range`, formátovací řetězce a můžete použít zápis na jeden řádek pomocí tzv _generátorové notace_.

# %%
# TODO: na jednom řádku vyřešte výše uvedené volání
f1(**{f'param{i}':f'hodnota{i}' for i in range(1, 101)})
# Out:
# param1=hodnota1
# param2=hodnota2
# param3=hodnota3
# param4=hodnota4
# param5=hodnota5
# param6=hodnota6
# param7=hodnota7
# param8=hodnota8
# param9=hodnota9
# param10=hodnota10
# param11=hodnota11
# param12=hodnota12
# param13=hodnota13
# param14=hodnota14
# param15=hodnota15
# param16=hodnota16
# param17=hodnota17
# param18=hodnota18
# param19=hodnota19
# param20=hodnota20
# param21=hodnota21
# param22=hodnota22
# param23=hodnota23
# param24=hodnota24
# param25=hodnota25
# param26=hodnota26
# param27=hodnota27
# param28=hodnota28
# param29=hodnota29
# param30=hodnota30
# param31=hodnota31
# param32=hodnota32
# param33=hodnota33
# param34=hodnota34
# param35=hodnota35
# param36=hodnota36
# param37=hodnota37
# param38=hodnota38
# param39=hodnota39
# param40=hodnota40
# param41=hodnota41
# param42=hodnota42
# param43=hodnota43
# param44=hodnota44
# param45=hodnota45
# param46=hodnota46
# param47=hodnota47
# param48=hodnota48
# param49=hodnota49
# param50=hodnota50
# param51=hodnota51
# param52=hodnota52
# param53=hodnota53
# param54=hodnota54
# param55=hodnota55
# param56=hodnota56
# param57=hodnota57
# param58=hodnota58
# param59=hodnota59
# param60=hodnota60
# param61=hodnota61
# param62=hodnota62
# param63=hodnota63
# param64=hodnota64
# param65=hodnota65
# param66=hodnota66
# param67=hodnota67
# param68=hodnota68
# param69=hodnota69
# param70=hodnota70
# param71=hodnota71
# param72=hodnota72
# param73=hodnota73
# param74=hodnota74
# param75=hodnota75
# param76=hodnota76
# param77=hodnota77
# param78=hodnota78
# param79=hodnota79
# param80=hodnota80
# param81=hodnota81
# param82=hodnota82
# param83=hodnota83
# param84=hodnota84
# param85=hodnota85
# param86=hodnota86
# param87=hodnota87
# param88=hodnota88
# param89=hodnota89
# param90=hodnota90
# param91=hodnota91
# param92=hodnota92
# param93=hodnota93
# param94=hodnota94
# param95=hodnota95
# param96=hodnota96
# param97=hodnota97
# param98=hodnota98
# param99=hodnota99
# param100=hodnota100

# %% [markdown]
# ## Část 2: Třídy
#
# Vytvořte třídu `Auto`, které má:
#
# - incializátor, který vezme argument `vykon` a nastaví jej do parametru objektu `vykon`
# - funkci, která zařídí, že když se zadá `print(instance_objektu)`, tak se vypíše `Auto(vykon=??)`, kde `??` bude nahrazeno parametrem objektu `vykon`
# - proměnnou `vykon`, která bude řízená přes tzv. _getter_ a _setter_ (viz `@property` kontrukce tak), že
#   - getter vrátí interní proměnnou `self.__vykon`
#   - setter nastaví tuto interní proměnnou, pouze když je hodnota nezáporná. Jinak vyvolá vyjímku `ValueError` s popisem `Vykon nemuze byt mensi nez 0, bylo zadano ??`.

# %%
#TODO: vytvorte tridu
class Auto:
    def __init__(self, vykon):
        self.vykon = vykon

    def __repr__(self):
        return f'Auto(vykon={self.vykon})'

    @property
    def vykon(self):
        return self.__vykon

    @vykon.setter
    def vykon(self, vykon):
        if vykon < 0:
            raise ValueError(f'Vykon nemuze byt mensi nez 0, bylo zadano {vykon}')
        else:
            self.__vykon = vykon

auto = Auto(vykon=15)
auto.vykon = 125
print("Muj objekt je", auto)
# Out:
# Muj objekt je Auto(vykon=125)

# %% [markdown]
# Test vyvolání vyjímky - zkusíme natastavit zápornou hodnotu výkonu auta.

# %%
auto = Auto(vykon=15)
auto.vykon = -100
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-5e2e5283e8f8> in <module>
#       1 auto = Auto(vykon=15)
# ----> 2 auto.vykon = -100
#
# <ipython-input-6-3eb97142609c> in vykon(self, vykon)
#      14     def vykon(self, vykon):
#      15         if vykon < 0:
# ---> 16             raise ValueError(f'Vykon nemuze byt mensi nez 0, bylo zadano {vykon}')
#      17         else:
#      18             self.__vykon = vykon
#
# ValueError: Vykon nemuze byt mensi nez 0, bylo zadano -100

# %% [markdown]
# Nyní je vaším úkolem napsat ošetření vyjímky, které při nastavení záporné hodnoty výkonu vypíše chybovou hlášku, kterou převezme z vyjímky (použijte konstrukci `ValueError as e` a vypište i proměnnou `e`)

# %%
#TODO: vytvorte konstrukci zachytavani chyby
try:
    auto = Auto(vykon=-100)
    print("Vse probehlo OK")
except ValueError as e:
    print(f'Došlo k chybě {e}', file=sys.stderr)
# Out:
# Došlo k chybě Vykon nemuze byt mensi nez 0, bylo zadano -100

# %% [markdown]
# ## Část 3: Smyčky, pole atd.
#
# Vytvoříme data, se kterými budeme pracovat

# %%
data = [
    ("Karel", "Procházka"),
    ("Lucie", "Nováková"),
    ("Přemysl", "Oráč")
]

# %% [markdown]
# Projdete data v cyklu s tím, že vypíšete:
# ```
# 1. Karel Procházka
# 2. Lucie Nováková
# 3. Přemysl Oráč
# ```
#
# Použijte jeden cyklus s tím, že budete plnit proměnné `rid`, `jmeno` a `prijmeni` - použijte funkce `enumerate` a rozbalení  (_upacking_).

# %%
#TODO: napiste cyklus
for num, (name, surname) in enumerate(data, start=1):
        print(f'{num}.', name, surname)
# Out:
# 1. Karel Procházka
# 2. Lucie Nováková
# 3. Přemysl Oráč

# %% [markdown]
# A vypište poslední prvek posle

# %%
#TODO: výpis posledního prvku
print(data[-1])
# Out:
# ('Přemysl', 'Oráč')
